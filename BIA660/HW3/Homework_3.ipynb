# %% [markdown]
# <h1><center>HW 3: Build Twitter Networks</center></h1>

# %% [markdown]
# ### Q1. Scrape the follower-followee network by companies.
#     * Define a function to retrieve the follower-followee network of a list of twenty accounts of U.S. FT companies.
#     * The input will be a list of Twitter screen names.
#     * The output will be a dataframe with this list of accounts as row index and column index, and 1 and 0 as values.
#     * Note: this will take some time because Twitter API will force you to sleep.

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import re
import numpy as np
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import tweepy
import datetime
import time

# %%
# define your function here

def get_follow(accounts):
    
    
    
    return

# %%
# test the function with the list of accounts

accounts=['walmart',
 'tysonfoods',
 'republicservice',
 'onsemi',
 'amkortechnology',
 'cbre',
 'smartfinal',
 'google',
 'ebay',
 'intuit',
 'intel',
 'paypal',
 'oracle',
 'netflix',
  'target']

get_follow(accounts)
# Out:
# Rate limit reached. Sleeping for: 717
#                  walmart  tysonfoods  republicservice  onsemi  \
# walmart            False        True            False   False
# tysonfoods          True       False            False   False
# republicservice    False       False            False   False
# onsemi             False       False            False   False
# amkortechnology    False       False            False    True
# cbre               False       False            False   False
# smartfinal         False        True            False   False
# google             False        True             True   False
# ebay               False       False            False   False
# intuit             False       False            False   False
# intel              False       False            False    True
# paypal             False       False            False   False
# oracle             False       False            False   False
# netflix            False       False            False   False
# target             False        True             True   False
#
#                  amkortechnology   cbre  smartfinal  google   ebay  intuit  \
# walmart                    False  False       False   False  False   False
# tysonfoods                 False  False        True   False  False   False
# republicservice            False  False       False   False  False   False
# onsemi                      True  False       False   False  False   False
# amkortechnology            False  False       False   False  False   False
# cbre                       False  False       False   False  False   False
# smartfinal                 False  False       False   False  False   False
# google                     False   True       False   False   True    True
# ebay                       False  False       False   False  False   False
# intuit                     False  False       False   False  False   False
# intel                       True  False       False   False  False    True
# paypal                     False  False       False   False   True   False
# oracle                     False  False       False   False  False   False
# netflix                    False  False       False   False  False   False
# target                     False  False       False   False  False   False
#
#                  intel  paypal  oracle  netflix  target
# walmart          False   False   False    False   False
# tysonfoods       False   False   False    False    True
# republicservice  False   False   False    False   False
# onsemi            True   False   False    False   False
# amkortechnology  False   False   False    False   False
# cbre             False   False   False    False   False
# smartfinal       False   False   False    False   False
# google            True   False   False    False    True
# ebay             False    True   False    False   False
# intuit           False   False   False    False    True
# intel            False   False    True    False    True
# paypal           False   False   False    False   False
# oracle            True   False   False    False   False
# netflix          False   False   False    False    True
# target           False   False   False    False   False

# %% [markdown]
# ### Q2. Build a directed network with the data you just scraped.
#     * Bulid a network and visualize it. Hint: you can use "nx.convert_matrix.from_pandas_adjacency".
#     * Calculate the indegree centrality and structural hole (you can use constraint).
#     * Sort these nodes by indegree centrality and print the top one account.
#     * Sort these nodes by structural hole and print the top one account.
#     * Note the NA values in constraint measures. Also note the relation between structural hole and constraint.

# %%
# Build a network from the adjacency matrix

# add your code here
# Out:
#                  walmart  tysonfoods  republicservice  onsemi  \
# walmart                0           1                0       0
# tysonfoods             1           0                0       0
# republicservice        0           0                0       0
# onsemi                 0           0                0       0
# amkortechnology        0           0                0       1
# cbre                   0           0                0       0
# smartfinal             0           1                0       0
# google                 0           1                1       0
# ebay                   0           0                0       0
# intuit                 0           0                0       0
# intel                  0           0                0       1
# paypal                 0           0                0       0
# oracle                 0           0                0       0
# netflix                0           0                0       0
# target                 0           1                1       0
#
#                  amkortechnology  cbre  smartfinal  google  ebay  intuit  \
# walmart                        0     0           0       0     0       0
# tysonfoods                     0     0           1       0     0       0
# republicservice                0     0           0       0     0       0
# onsemi                         1     0           0       0     0       0
# amkortechnology                0     0           0       0     0       0
# cbre                           0     0           0       0     0       0
# smartfinal                     0     0           0       0     0       0
# google                         0     1           0       0     1       1
# ebay                           0     0           0       0     0       0
# intuit                         0     0           0       0     0       0
# intel                          1     0           0       0     0       1
# paypal                         0     0           0       0     1       0
# oracle                         0     0           0       0     0       0
# netflix                        0     0           0       0     0       0
# target                         0     0           0       0     0       0
#
#                  intel  paypal  oracle  netflix  target
# walmart              0       0       0        0       0
# tysonfoods           0       0       0        0       1
# republicservice      0       0       0        0       0
# onsemi               1       0       0        0       0
# amkortechnology      0       0       0        0       0
# cbre                 0       0       0        0       0
# smartfinal           0       0       0        0       0
# google               1       0       0        0       1
# ebay                 0       1       0        0       0
# intuit               0       0       0        0       1
# intel                0       0       1        0       1
# paypal               0       0       0        0       0
# oracle               1       0       0        0       0
# netflix              0       0       0        0       1
# target               0       0       0        0       0
# Text(0.5, 1.0, 'The follower-followee network of Fortune companies')
# (-1.2009815705603601,
#  1.209143045166369,
#  -0.9296342477802748,
#  1.135240478101184)

# %%
# calculate centrality


# calculate constraint


# get the top accounts
# Out:
# {'walmart': 0.07142857142857142,
#  'tysonfoods': 0.2857142857142857,
#  'republicservice': 0.14285714285714285,
#  'onsemi': 0.14285714285714285,
#  'amkortechnology': 0.14285714285714285,
#  'cbre': 0.07142857142857142,
#  'smartfinal': 0.07142857142857142,
#  'google': 0.0,
#  'ebay': 0.14285714285714285,
#  'intuit': 0.14285714285714285,
#  'intel': 0.21428571428571427,
#  'paypal': 0.07142857142857142,
#  'oracle': 0.07142857142857142,
#  'netflix': 0.0,
#  'target': 0.3571428571428571}
# {'walmart': 1.0,
#  'tysonfoods': 0.29071220324864633,
#  'onsemi': 0.7608506944444444,
#  'amkortechnology': 1.0069444444444444,
#  'smartfinal': 1.0,
#  'google': 0.2812557846267758,
#  'ebay': 0.5555555555555556,
#  'intuit': 0.5408871882086166,
#  'intel': 0.33003826530612246,
#  'paypal': 1.0,
#  'oracle': 1.0,
#  'netflix': 1.0,
#  'target': 0.3208226317737979}
# 'target'
# 'tysonfoods'

# %% [markdown]
# ### Bonus question:
#  * Define a functionn to scrape the most recent (the recent week, but you can go beyond a bit if in one call you get a few) **original** (exclude retweets) tweets from multiple accouts.
#  * For each tweet, grab "id","created_at","full_text","user.screen_name".
#  * Make a dataframe and return the dataframe.
#  * Use the function to get the original tweets of the top twp accounts from Q2.

# %%
# scrape recent tweets
# Out:
#                        0                   1  \
# 0    1494852783840931840 2022-02-19 01:54:11
# 1    1494851036447752196 2022-02-19 01:47:14
# 2    1494850452747440130 2022-02-19 01:44:55
# 3    1494848243360010240 2022-02-19 01:36:08
# 4    1494847186408034306 2022-02-19 01:31:56
# ..                   ...                 ...
# 832  1472242890327875592 2021-12-18 16:30:32
# 833  1471526727897780226 2021-12-16 17:04:46
# 834  1468981591749894148 2021-12-09 16:31:18
# 835  1468265635134287883 2021-12-07 17:06:21
# 836  1467886105114689543 2021-12-06 15:58:14
#
#                                                      2           3
# 0    b"@andbreww if it's meant to be, it will be \x...      Target
# 1          b"@jckeperqlta it's true, i was the target"      Target
# 2    b'@pricedemption my heart when yennefer: \xf0\...      Target
# 3      b'@RachiesArt the colors are giving monet, tbh'      Target
# 4    b'@jckeperqlta i have so many feelings, okay \...      Target
# ..                                                 ...         ...
# 832  b'We\xe2\x80\x99re honored to partner with @Wr...  TysonFoods
# 833  b'@lejaz1 Hi \xe2\x80\x93 Thank you for bringi...  TysonFoods
# 834  b'@missfab_ @kroger Hi \xe2\x80\x93 Thank you ...  TysonFoods
# 835  b'@thelaughbarrel Hi \xe2\x80\x93 Thank you fo...  TysonFoods
# 836  b'@BrianQuesenbery Hi \xe2\x80\x93 Thank you f...  TysonFoods
#
# [837 rows x 4 columns]
